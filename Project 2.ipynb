# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Yahia Hassanin </b>
#
# <b> Mechanical Engineering student </b>

# %% [markdown]
# <i> I am interested in data science because a lot of research in my uses data science to optimize outcomes </i>

# %% [markdown]
# ### Multiply 5*5

# %%
5*5
# Out:
# 25

# %% [markdown]
# <ol>
# <li>One</li>
# <li>Two</li>
# <li>Three</li>
# </ol>

# %% [markdown]
# <tr>
# <th>One</th>
# <th>Two</th>
# <th>Three</th>
# </tr>
#
# <tr>
# <td>One</td>
# <td>Two</td>
# <td>Three</td>
# </tr>
